# %% [markdown]
# # IQA - Química Tecnológica Ambiental
#
# **Grupo: Antonio Fuziy e André Rocco**
#
# ## Rio Avecuía
# ___

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Importing excel to see all the amount of data from the parameters of the IQA

# %%
df = pd.read_excel("./excel/geral.xlsx", engine='openpyxl')

# %%
df["Parametro"].value_counts().head()
# Out:
# Temperatura do Ar      21
# Coloração              21
# Fósforo Total          21
# Nitrogênio-Nitrato     21
# Temperatura da Água    21
# Name: Parametro, dtype: int64

# %% [markdown]
# ___
# #### Reading Data

# %%
dbo = pd.read_excel("./excel/dbo.xlsx", engine='openpyxl')
turbidez = pd.read_excel("./excel/turbidez.xlsx", engine='openpyxl')
nitrogenio = pd.read_excel("./excel/nitrogenio.xlsx", engine='openpyxl')
oxigenio = pd.read_excel("./excel/oxigenio.xlsx", engine='openpyxl')
ph = pd.read_excel("./excel/ph.xlsx", engine='openpyxl')
temperatura = pd.read_excel("./excel/temperatura.xlsx", engine='openpyxl')
fosforo = pd.read_excel("./excel/fosforo.xlsx", engine='openpyxl')
residuos = pd.read_excel("./excel/residuos.xlsx", engine='openpyxl')
ecolif = pd.read_excel("./excel/ecoliformes.xlsx", engine='openpyxl')
temperatura_ar = pd.read_excel("./excel/temperatura_ar.xlsx", engine='openpyxl')
nit_total = pd.read_excel("./excel/nit_total.xlsx", engine='openpyxl')

# %% [markdown]
# ___
# **Changing Temperature and Coliformes**

# %%
coliformes = pd.DataFrame()
coliformes["Valor"] = ecolif["Valor"]*1.25

temperatura_data = pd.DataFrame()
temperatura_data["Valor"] = temperatura_ar["Valor"] - temperatura["Valor"]

# %% [markdown]
# ___
# **Creating a dataframe with all the IQA parameters values**

# %%
_data = pd.DataFrame()
_data["DBO"] = dbo["Valor"]
_data["Oxigenio"] = oxigenio["Valor"]
_data["Nitrogenio"] = nitrogenio["Valor"]
_data["Nit_Total"] = nit_total["Valor"]
_data["Fosforo"] = fosforo["Valor"]
_data["Temperatura Agua"] = temperatura["Valor"]
_data["Temperatura"] = temperatura_data["Valor"]
_data["Residuos"] = residuos["Valor"]
_data["pH"] = ph["Valor"]
_data["Turbidez"] = turbidez["Valor"]
_data["Coliformes"] = coliformes["Valor"]
_data = _data.set_index(pd.to_datetime(dbo["Data Coleta"].values))
_data
# Out:
#             DBO  Oxigenio  Nitrogenio  Nit_Total  Fosforo  Temperatura Agua  \
# 2017-03-01  2.0      4.70        0.18       0.68     0.05              29.7
# 2017-02-03  2.0      4.70        0.25       0.48     0.05              27.9
# 2017-05-18  2.0      6.50        0.25       0.57     0.03              19.5
# 2017-06-07  2.0      8.80        0.44       1.11     0.02              17.5
# 2017-09-14  2.0      6.80        0.14       0.84     0.02              21.5
# 2017-11-16  2.0      5.60        0.13       1.17     0.05              28.8
# 2018-11-01  2.0      5.30        0.41       0.80     0.07              23.6
# 2018-06-03  2.0      4.50        0.18       0.61     0.07              26.2
# 2018-03-05  2.0      5.80        0.24       0.90     0.04              26.1
# 2018-12-07  2.0      6.30        0.22       0.81     0.03              20.0
# 2018-09-18  2.0      4.90        0.11       0.71     1.80              21.5
# ...

# %% [markdown]
# ___
# #### Ploting Data

# %%
plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["DBO"], "bo", markersize=10)
plt.title("DBO")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Oxigenio"], "bo", markersize=10)
plt.title("Oxigenio")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Nitrogenio"], "bo", markersize=10)
plt.title("Nitrogenio")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Residuos"], "bo", markersize=10)
plt.title("Residuos")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Temperatura"], "bo", markersize=10)
plt.title("Temperatura")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["pH"], "bo", markersize=10)
plt.title("pH")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Fosforo"], "bo", markersize=10)
plt.title("Fosforo")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Turbidez"], "bo", markersize=10)
plt.title("Turbidez")
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(_data.index, _data["Coliformes"], "bo", markersize=10)
plt.title("Coliformes")
plt.grid(True)
plt.show()

# %% [markdown]
# ___
# **Reading all the csv data collected from the IQA Graphics given**

# %%
turb_csv = pd.read_csv("./csv/turbidez.csv")
nit_csv = pd.read_csv("./csv/nit_total.csv")
dbo_csv = pd.read_csv("./csv/dbo.csv")
fosf_csv = pd.read_csv("./csv/fosforo.csv")
temp_csv = pd.read_csv("./csv/temperatura.csv")
res_csv = pd.read_csv("./csv/residuos.csv")
ph_csv = pd.read_csv("./csv/ph.csv")
coli_csv = pd.read_csv("./csv/coliformes.csv")
oxi_csv = pd.read_csv("./csv/oxi_porcentagem.csv")

# %%
q_data = pd.DataFrame()
q_data["DBO"] = dbo_csv.iloc[0:,1]
q_data["Nitrogenio"] = nit_csv.iloc[0:,1]
q_data["Coliformes"] = coli_csv.iloc[:,1]
q_data["pH"] = ph_csv.iloc[:,1]
q_data["Oxigenio"] = oxi_csv.iloc[:,1]
q_data["Temperatura"] = temp_csv.iloc[:,1]
q_data["Fosforo"] = fosf_csv.iloc[:,1]
q_data["Turbidez"] = turb_csv.iloc[:,1]
q_data["Residuos"] = res_csv.iloc[0:,1]
q_data
# Out:
#          DBO  Nitrogenio  Coliformes         pH   Oxigenio  Temperatura  \
# 0  84.394509   97.872325   94.658156  84.770642  58.301063    79.624665
# 1  84.394509   96.009192   97.330496  90.642202  82.313879    16.890080
# 2  84.394509   90.954546   87.699291  91.559633  50.208880    92.761394
# 3  84.394509   92.551011   91.178723  88.623853  49.130697    77.211796
# 4  84.394509   91.752424   86.361702  86.972477  75.567245    64.343164
# 5  84.394509   92.816970   98.400000  86.972477  38.877062    25.469169
# 6  84.394509   90.157377   96.795745  83.486239  90.952419    54.959786
# 7  59.498761   91.486464   83.687943  91.559633  94.766745    92.761394
#
#      Fosforo   Turbidez   Residuos
# 0  97.252747  68.219507  88.028916
# 1  99.175824  76.225253  89.093468
# 2  98.076923  55.149903  88.305488
# 3  29.395604  55.949198  87.774980
# 4  96.978022  62.350666  88.297707
# 5  98.351648  59.949226  88.830337
# 6  98.351648  66.620207  89.093468
# ...

# %% [markdown]
# ___
# **w_list**

# %%
w_pH = 0.12
w_DBO = 0.10
w_OD = 0.17
w_temp = 0.10
w_nitro = 0.10
w_turb = 0.08
w_fos = 0.1
w_res = 0.08
w_fosf = 0.1
w_coli = 0.15
w_list = [w_DBO, w_nitro, w_coli, w_pH, w_OD, w_temp, w_fosf, w_turb, w_res]

# %% [markdown]
# ___
# **IQA calculate function**

# %%
def IQA(q_list, w_list):
    IQA_value = 1
    for i in range(0, len(q_list)):
        IQA_value *= q_list[i]**w_list[i]
    return IQA_value

# %%
iqa1 = IQA(q1, w_list)
iqa2 = IQA(q2, w_list)
iqa3 = IQA(q3, w_list)
iqa4 = IQA(q4, w_list)
iqa5 = IQA(q5, w_list)
iqa6 = IQA(q6, w_list)
iqa7 = IQA(q7, w_list)
iqa8 = IQA(q8, w_list)

# %%
iqa_list = [iqa1, iqa2, iqa3, iqa4, iqa5, iqa6, iqa7, iqa8]

# %%
iqa_dates = [_data.index[1], _data.index[4], _data.index[7], _data.index[10], _data.index[13], _data.index[16], _data.index[18], _data.index[19]]
print(iqa_dates)
# Out:
# [Timestamp('2017-02-03 00:00:00'), Timestamp('2017-09-14 00:00:00'), Timestamp('2018-06-03 00:00:00'), Timestamp('2018-09-18 00:00:00'), Timestamp('2019-03-14 00:00:00'), Timestamp('2019-12-09 00:00:00'), Timestamp('2020-10-03 00:00:00'), Timestamp('2020-11-17 00:00:00')]

# %%
plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["DBO"], "-pb")
plt.title("DBO")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Nitrogenio"], "-pb")
plt.title("Nitrogenio")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Coliformes"], "-pb")
plt.title("Coliformes")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["pH"], "-pb")
plt.title("pH")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Oxigenio"], "-pb")
plt.title("Oxigenio")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Temperatura"], "-pb")
plt.title("Temperatura")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Fosforo"], "-pb")
plt.title("Fosforo")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Turbidez"], "-pb")
plt.title("Turbidez")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(iqa_dates, q_data["Residuos"], "-pb")
plt.title("Residuos")
plt.show()

# %% [markdown]
# ___
# **IQA from Avecuía River**

# %%
plt.figure(figsize=(10,5))
plt.plot(iqa_dates, iqa_list, "-pb")
plt.title("IQA")
plt.show()
